# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
RoBERTa_conven = pd.DataFrame(columns = [[13, 21, 42, 87, 100]], index = [['CoLA', 'SST-2', 'MRPC(F1)', 'MRPC(Acc)', 'QQP(F1)', 'QQP(Acc)', 'MNLI-m', 'MNLI-mm', 'QNLI', 'RTE', 'WNLI']])

RoBERTa_VQ_rate_0 = pd.DataFrame(columns = [[13, 21, 42, 87, 100]], index = [['CoLA', 'SST-2', 'MRPC(F1)', 'MRPC(Acc)', 'QQP(F1)', 'QQP(Acc)', 'MNLI-m', 'MNLI-mm', 'QNLI', 'RTE', 'WNLI']])
RoBERTa_VQ_rate_02 = pd.DataFrame(columns = [[13, 21, 42, 87, 100]], index = [['CoLA', 'SST-2', 'MRPC(F1)', 'MRPC(Acc)', 'QQP(F1)', 'QQP(Acc)', 'MNLI-m', 'MNLI-mm', 'QNLI', 'RTE', 'WNLI']])
RoBERTa_VQ_rate_04 = pd.DataFrame(columns = [[13, 21, 42, 87, 100]], index = [['CoLA', 'SST-2', 'MRPC(F1)', 'MRPC(Acc)', 'QQP(F1)', 'QQP(Acc)', 'MNLI-m', 'MNLI-mm', 'QNLI', 'RTE', 'WNLI']])
RoBERTa_VQ_BEST = pd.DataFrame(columns = [[13, 21, 42, 87, 100]], index = [['CoLA', 'SST-2', 'MRPC(F1)', 'MRPC(Acc)', 'QQP(F1)', 'QQP(Acc)', 'MNLI-m', 'MNLI-mm', 'QNLI', 'RTE', 'WNLI']])

RoBERTa_EDA = pd.DataFrame(columns = [[13, 21, 42, 87, 100]], index = [['CoLA', 'SST-2', 'MRPC(F1)', 'MRPC(Acc)', 'QQP(F1)', 'QQP(Acc)', 'MNLI-m', 'MNLI-mm', 'QNLI', 'RTE', 'WNLI']])
RoBERTa_GAN = pd.DataFrame(columns = [[13, 21, 42, 87, 100]], index = [['CoLA', 'SST-2', 'MRPC(F1)', 'MRPC(Acc)', 'QQP(F1)', 'QQP(Acc)', 'MNLI-m', 'MNLI-mm', 'QNLI', 'RTE', 'WNLI']])

# %%
table_RoBERTa_conven = [[1.9,17,31.8,11.3,24],
[74.2,61.4,83.4,82.3,61.6],
[77.3,55.9,72.9,61.8,71.4],
[65.3,47.8,63.1,53.7,63.7],
[42,42.3,33.6,44.9,33.4],
[68.6,61,60.1,51.1,70.5],
[32.7,32.9,34.4,34.3,33.8],
[35.7,34.6,34,35.1,34.5],
[48.1,47.5,50.5,46.6,46.3],
[50.3,49.3,50.3,47.5,51],
[61.6,48.6,63,54.8,58.9]
]

for i in range(len(table_RoBERTa_conven)):
    RoBERTa_conven.iloc[i] = table_RoBERTa_conven[i]
RoBERTa_conven
# Out:
#             13    21    42    87    100
# CoLA        1.9    17  31.8  11.3    24
# SST-2      74.2  61.4  83.4  82.3  61.6
# MRPC(F1)   77.3  55.9  72.9  61.8  71.4
# MRPC(Acc)  65.3  47.8  63.1  53.7  63.7
# QQP(F1)      42  42.3  33.6  44.9  33.4
# QQP(Acc)   68.6    61  60.1  51.1  70.5
# MNLI-m     32.7  32.9  34.4  34.3  33.8
# MNLI-mm    35.7  34.6    34  35.1  34.5
# QNLI       48.1  47.5  50.5  46.6  46.3
# RTE        50.3  49.3  50.3  47.5    51
# WNLI       61.6  48.6    63  54.8  58.9

# %%
table_RoBERTa_VQ_rate_0 = [[39.2,17.9,11.4,33.1,40],
[78.3,63.3,78.4,87.1,83.6],
[68,79.9,72.9,62.1,77],
[61.4,66.5,62.7,55,70.6],
[37.5,46.6,37.2,45,34.8],
[73.2,77.1,63.3,81.3,60],
[35.6,36.8,32.7,33,34.9],
[35.5,40.2,32.4,36.5,35.4],
[48.5,50.5,48.6,47.2,46.3],
[50.3,50.9,49.7,49.9,50.4],
[65.1,54.1,65.1,63,57.5]]

for i in range(len(table_RoBERTa_VQ_rate_0)):
    RoBERTa_VQ_rate_0.iloc[i] = table_RoBERTa_VQ_rate_0[i]
RoBERTa_VQ_rate_0
# Out:
#             13    21    42    87    100
# CoLA       39.2  17.9  11.4  33.1    40
# SST-2      78.3  63.3  78.4  87.1  83.6
# MRPC(F1)     68  79.9  72.9  62.1    77
# MRPC(Acc)  61.4  66.5  62.7    55  70.6
# QQP(F1)    37.5  46.6  37.2    45  34.8
# QQP(Acc)   73.2  77.1  63.3  81.3    60
# MNLI-m     35.6  36.8  32.7    33  34.9
# MNLI-mm    35.5  40.2  32.4  36.5  35.4
# QNLI       48.5  50.5  48.6  47.2  46.3
# RTE        50.3  50.9  49.7  49.9  50.4
# WNLI       65.1  54.1  65.1    63  57.5

# %%
table_RoBERTa_VQ_rate_02 = [[31.2, 20.9, 43, 21.8, 31.4],
[74.3, 69, 77.8, 87, 76.1],
[67.3, 79.9, 71.6, 70.6, 73.1],
[59.3, 66.5, 60.6, 61.2, 64.6],
[49.2, 40.9, 36.3, 40.9, 38.9],
[78.5, 57.8, 71.7, 65.8, 59.6],
[33.1, 33.8, 34.3, 35.4, 35.4],
[36.5, 33.6, 34.2, 33.8, 35.2],
[50.9, 47.8, 51.6, 49.1, 48.8],
[50.3, 49.6, 49.9, 49.2, 51.1],
[65.1, 54.8, 54.8, 62.3, 58.9]]

for i in range(len(table_RoBERTa_VQ_rate_02)):
    RoBERTa_VQ_rate_02.iloc[i] = table_RoBERTa_VQ_rate_02[i]
RoBERTa_VQ_rate_02
# Out:
#             13    21    42    87    100
# CoLA       31.2  20.9    43  21.8  31.4
# SST-2      74.3    69  77.8    87  76.1
# MRPC(F1)   67.3  79.9  71.6  70.6  73.1
# MRPC(Acc)  59.3  66.5  60.6  61.2  64.6
# QQP(F1)    49.2  40.9  36.3  40.9  38.9
# QQP(Acc)   78.5  57.8  71.7  65.8  59.6
# MNLI-m     33.1  33.8  34.3  35.4  35.4
# MNLI-mm    36.5  33.6  34.2  33.8  35.2
# QNLI       50.9  47.8  51.6  49.1  48.8
# RTE        50.3  49.6  49.9  49.2  51.1
# WNLI       65.1  54.8  54.8  62.3  58.9

# %%
table_RoBERTa_VQ_rate_04 = [[14.6, 20.5, 20.4, 13.2, 22.8],
[80.5, 60.3, 75.2, 79.7, 76.4],
[64.7, 79.9, 75.3, 62.3, 75.9],
[58.1, 66.5, 66.8, 54.4, 69.2],
[35.9, 40.5, 37.7, 43.1, 37.6],
[60.8, 77.7, 71.8, 65.1, 50.8],
[36, 34.1, 34.4, 35.9, 33],
[33.3, 33.6, 37.9, 38.8, 34.4],
[48.7, 49.4, 48.7, 48.8, 49.1],
[50.7, 49.2, 50.8, 49.4, 51],
[66.4, 59.6, 65.1, 63, 58.9],
]

for i in range(len(table_RoBERTa_VQ_rate_04)):
    RoBERTa_VQ_rate_04.iloc[i] = table_RoBERTa_VQ_rate_04[i]
RoBERTa_VQ_rate_04
# Out:
#             13    21    42    87    100
# CoLA       14.6  20.5  20.4  13.2  22.8
# SST-2      80.5  60.3  75.2  79.7  76.4
# MRPC(F1)   64.7  79.9  75.3  62.3  75.9
# MRPC(Acc)  58.1  66.5  66.8  54.4  69.2
# QQP(F1)    35.9  40.5  37.7  43.1  37.6
# QQP(Acc)   60.8  77.7  71.8  65.1  50.8
# MNLI-m       36  34.1  34.4  35.9    33
# MNLI-mm    33.3  33.6  37.9  38.8  34.4
# QNLI       48.7  49.4  48.7  48.8  49.1
# RTE        50.7  49.2  50.8  49.4    51
# WNLI       66.4  59.6  65.1    63  58.9

# %%
table_RoBERTa_VQ_BEST = [[31.2, 20.9, 43, 21.8, 31.4],
[78.3, 63.3, 78.4, 87.1, 83.6],
[67.3, 79.9, 71.6, 70.6, 73.1],
[61.4, 66.5, 62.7, 55, 70.6],
[49.2, 40.9, 36.3, 40.9, 38.9],
[73.2, 77.1, 63.3, 81.3, 60],
[36, 34.1, 34.4, 35.9, 33],
[35.5, 40.2, 32.4, 36.5, 35.4],
[50.9, 47.8, 51.6, 49.1, 48.8],
[50.3, 50.9, 49.7, 49.9, 50.4],
[66.4, 59.6, 65.1, 63, 58.9]
]

for i in range(len(table_RoBERTa_VQ_BEST)):
    RoBERTa_VQ_BEST.iloc[i] = table_RoBERTa_VQ_BEST[i]
RoBERTa_VQ_BEST
# Out:
#             13    21    42    87    100
# CoLA       31.2  20.9    43  21.8  31.4
# SST-2      78.3  63.3  78.4  87.1  83.6
# MRPC(F1)   67.3  79.9  71.6  70.6  73.1
# MRPC(Acc)  61.4  66.5  62.7    55  70.6
# QQP(F1)    49.2  40.9  36.3  40.9  38.9
# QQP(Acc)   73.2  77.1  63.3  81.3    60
# MNLI-m       36  34.1  34.4  35.9    33
# MNLI-mm    35.5  40.2  32.4  36.5  35.4
# QNLI       50.9  47.8  51.6  49.1  48.8
# RTE        50.3  50.9  49.7  49.9  50.4
# WNLI       66.4  59.6  65.1    63  58.9

# %%
table_RoBERTa_EDA = [[4, 15.6, 21.1, 4.9, 16.5],
[68.1, 68.5, 76.5, 79.2, 60.1],
[73.6, 42.1, 80.7, 68.2, 78.8],
[61.4, 45.6, 69.9, 57.8, 69.7],
[32.7, 36.5, 31.8, 40.8, 33.2],
[38.4, 50.1, 81.6, 77.5, 38.5],
[33.5, 36, 32.5, 34, 32.9],
[32.2, 37.9, 32, 32.1, 35.2],
[49.8, 49.1, 49.8, 50.5, 46.9],
[50.8, 51.8, 50.1, 50.3, 51.8],
[47.9, 52.1, 64.4, 48.6, 54.8]]

for i in range(len(table_RoBERTa_EDA)):
    RoBERTa_EDA.iloc[i] = table_RoBERTa_EDA[i]
RoBERTa_EDA
# Out:
#             13    21    42    87    100
# CoLA          4  15.6  21.1   4.9  16.5
# SST-2      68.1  68.5  76.5  79.2  60.1
# MRPC(F1)   73.6  42.1  80.7  68.2  78.8
# MRPC(Acc)  61.4  45.6  69.9  57.8  69.7
# QQP(F1)    32.7  36.5  31.8  40.8  33.2
# QQP(Acc)   38.4  50.1  81.6  77.5  38.5
# MNLI-m     33.5    36  32.5    34  32.9
# MNLI-mm    32.2  37.9    32  32.1  35.2
# QNLI       49.8  49.1  49.8  50.5  46.9
# RTE        50.8  51.8  50.1  50.3  51.8
# WNLI       47.9  52.1  64.4  48.6  54.8

# %%
table_RoBERTa_GAN = [[14.5, 21.5, 26.1, 11.7, 35.7],
[76.9, 67.7, 83.9, 81.5, 69.1],
[61, 70.5, 70.2, 70.1, 75.8],
[55.5, 60.8, 59.3, 59.9, 69.3],
[34.7, 38, 31.2, 42.2, 33.4],
[55.5, 68, 68.5, 63.4, 60.2],
[33.9, 33.7, 34.7, 31.3, 33.3],
[34.6, 34.1, 34.4, 36.5, 35.2],
[50.5, 49, 49.5, 50.5, 48.7],
[50.3, 48.6, 50, 48.1, 50.7],
[56.8, 54.1, 63.7, 61.6, 40.4]
]

for i in range(len(table_RoBERTa_GAN)):
    RoBERTa_GAN.iloc[i] = table_RoBERTa_GAN[i]
RoBERTa_GAN
# Out:
#             13    21    42    87    100
# CoLA       14.5  21.5  26.1  11.7  35.7
# SST-2      76.9  67.7  83.9  81.5  69.1
# MRPC(F1)     61  70.5  70.2  70.1  75.8
# MRPC(Acc)  55.5  60.8  59.3  59.9  69.3
# QQP(F1)    34.7    38  31.2  42.2  33.4
# QQP(Acc)   55.5    68  68.5  63.4  60.2
# MNLI-m     33.9  33.7  34.7  31.3  33.3
# MNLI-mm    34.6  34.1  34.4  36.5  35.2
# QNLI       50.5    49  49.5  50.5  48.7
# RTE        50.3  48.6    50  48.1  50.7
# WNLI       56.8  54.1  63.7  61.6  40.4

# %%
BERT_conven = pd.DataFrame(columns = [[13, 21, 42, 87, 100]], index = [['CoLA', 'SST-2', 'MRPC(F1)', 'MRPC(Acc)', 'QQP(F1)', 'QQP(Acc)', 'MNLI-m', 'MNLI-mm', 'QNLI', 'RTE', 'WNLI']])

BERT_VQ_rate_0 = pd.DataFrame(columns = [[13, 21, 42, 87, 100]], index = [['CoLA', 'SST-2', 'MRPC(F1)', 'MRPC(Acc)', 'QQP(F1)', 'QQP(Acc)', 'MNLI-m', 'MNLI-mm', 'QNLI', 'RTE', 'WNLI']])
BERT_VQ_rate_02 = pd.DataFrame(columns = [[13, 21, 42, 87, 100]], index = [['CoLA', 'SST-2', 'MRPC(F1)', 'MRPC(Acc)', 'QQP(F1)', 'QQP(Acc)', 'MNLI-m', 'MNLI-mm', 'QNLI', 'RTE', 'WNLI']])
BERT_VQ_rate_04 = pd.DataFrame(columns = [[13, 21, 42, 87, 100]], index = [['CoLA', 'SST-2', 'MRPC(F1)', 'MRPC(Acc)', 'QQP(F1)', 'QQP(Acc)', 'MNLI-m', 'MNLI-mm', 'QNLI', 'RTE', 'WNLI']])
BERT_VQ_BEST = pd.DataFrame(columns = [[13, 21, 42, 87, 100]], index = [['CoLA', 'SST-2', 'MRPC(F1)', 'MRPC(Acc)', 'QQP(F1)', 'QQP(Acc)', 'MNLI-m', 'MNLI-mm', 'QNLI', 'RTE', 'WNLI']])

BERT_EDA = pd.DataFrame(columns = [[13, 21, 42, 87, 100]], index = [['CoLA', 'SST-2', 'MRPC(F1)', 'MRPC(Acc)', 'QQP(F1)', 'QQP(Acc)', 'MNLI-m', 'MNLI-mm', 'QNLI', 'RTE', 'WNLI']])
BERT_GAN = pd.DataFrame(columns = [[13, 21, 42, 87, 100]], index = [['CoLA', 'SST-2', 'MRPC(F1)', 'MRPC(Acc)', 'QQP(F1)', 'QQP(Acc)', 'MNLI-m', 'MNLI-mm', 'QNLI', 'RTE', 'WNLI']])

# %%
table_BERT_conven = [[4.7, 12.4, 7, 3.4, 13.4],
[64.3, 73.8, 69.4, 84.8, 84.5],
[62.7, 37.9, 67.2, 74.5, 79.8],
[54.6, 43.7, 58.4, 62.1, 67.4],
[33.5, 34.4, 29.8, 43, 35.9],
[60.6, 67, 51.6, 69.5, 46.9],
[32.7, 31.2, 31.2, 32.7, 33.8],
[36.5, 30.5, 31.1, 34.6, 34.6],
[50.5, 47.6, 46.4, 50.6, 49.5],
[50, 48.9, 49.2, 49.9, 49.8],
[48.6, 42.5, 34.9, 63, 50]
]

for i in range(len(table_BERT_conven)):
    BERT_conven.iloc[i] = table_BERT_conven[i]
BERT_conven
# Out:
#             13    21    42    87    100
# CoLA        4.7  12.4     7   3.4  13.4
# SST-2      64.3  73.8  69.4  84.8  84.5
# MRPC(F1)   62.7  37.9  67.2  74.5  79.8
# MRPC(Acc)  54.6  43.7  58.4  62.1  67.4
# QQP(F1)    33.5  34.4  29.8    43  35.9
# QQP(Acc)   60.6    67  51.6  69.5  46.9
# MNLI-m     32.7  31.2  31.2  32.7  33.8
# MNLI-mm    36.5  30.5  31.1  34.6  34.6
# QNLI       50.5  47.6  46.4  50.6  49.5
# RTE          50  48.9  49.2  49.9  49.8
# WNLI       48.6  42.5  34.9    63    50

# %%
table_BERT_VQ_rate_0 = [[-2.4, 9.7, 8.4, 13.2, 18.3],
[71.2, 74.4, 74.6, 84.1, 82.4],
[51.4, 57.9, 77.3, 75.2, 79.2],
[49.2, 51.9, 65, 64, 67.4],
[61.2, 32.6, 30.8, 42.4, 35.8],
[58.8, 74.4, 70.1, 69.1, 62.5],
[34.1, 32.7, 33.5, 35.4, 35.9],
[34.7, 32, 32.2, 38.8, 37.7],
[50.6, 48, 53.3, 50.5, 48.9],
[49.9, 49.2, 49.8, 49.5, 48.7],
[54.1, 41.8, 53.4, 63, 51.4],
]

for i in range(len(table_BERT_VQ_rate_0)):
    BERT_VQ_rate_0.iloc[i] = table_BERT_VQ_rate_0[i]
BERT_VQ_rate_0
# Out:
#             13    21    42    87    100
# CoLA       -2.4   9.7   8.4  13.2  18.3
# SST-2      71.2  74.4  74.6  84.1  82.4
# MRPC(F1)   51.4  57.9  77.3  75.2  79.2
# MRPC(Acc)  49.2  51.9    65    64  67.4
# QQP(F1)    61.2  32.6  30.8  42.4  35.8
# QQP(Acc)   58.8  74.4  70.1  69.1  62.5
# MNLI-m     34.1  32.7  33.5  35.4  35.9
# MNLI-mm    34.7    32  32.2  38.8  37.7
# QNLI       50.6    48  53.3  50.5  48.9
# RTE        49.9  49.2  49.8  49.5  48.7
# WNLI       54.1  41.8  53.4    63  51.4

# %%
table_BERT_VQ_rate_02 = [[6.3, 12.9, 12.2, 10.3, 20.2],
[71.2, 72.5, 79.4, 86.1, 75.8],
[75.4, 59.8, 74.6, 68.5, 79.8],
[63, 53.3, 64, 57.9, 67.8],
[33.2, 35, 32.5, 42.8, 38.6],
[70.5, 73.6, 55.8, 72.7, 41.2],
[32.2, 31.2, 33.9, 34.4, 35.6],
[35.9, 32.2, 33.1, 35.5, 34.5],
[50, 50.5, 51.1, 50.7, 48.3],
[50, 48, 50.3, 50.2, 48.8],
[54.1, 43.8, 50.7, 63, 44.5]
]

for i in range(len(table_BERT_VQ_rate_02)):
    BERT_VQ_rate_02.iloc[i] = table_BERT_VQ_rate_02[i]
BERT_VQ_rate_02
# Out:
#             13    21    42    87    100
# CoLA        6.3  12.9  12.2  10.3  20.2
# SST-2      71.2  72.5  79.4  86.1  75.8
# MRPC(F1)   75.4  59.8  74.6  68.5  79.8
# MRPC(Acc)    63  53.3    64  57.9  67.8
# QQP(F1)    33.2    35  32.5  42.8  38.6
# QQP(Acc)   70.5  73.6  55.8  72.7  41.2
# MNLI-m     32.2  31.2  33.9  34.4  35.6
# MNLI-mm    35.9  32.2  33.1  35.5  34.5
# QNLI         50  50.5  51.1  50.7  48.3
# RTE          50    48  50.3  50.2  48.8
# WNLI       54.1  43.8  50.7    63  44.5

# %%
table_BERT_VQ_rate_04 = [[15.9, 9, 3.5, -0.1, 19.8],
[80.3, 75.8, 71.8, 80.6, 84.5],
[69.3, 58.3, 68.8, 73.4, 80],
[60.9, 52.1, 66.3, 61.4, 62.6],
[38.2, 37.4, 31.6, 42, 34.9],
[60.4, 68.9, 66.7, 71.4, 51.5],
[31.7, 33.1, 32.3, 34.5, 36.3],
[32.3, 29.1, 36, 34.6, 38.1],
[53.7, 51.9, 52.2, 49.8, 51.3],
[50, 49.1, 50.3, 49.1, 49.3],
[55.5, 45.9, 58.2, 58.9, 43.2]
]

for i in range(len(table_BERT_VQ_rate_04)):
    BERT_VQ_rate_04.iloc[i] = table_BERT_VQ_rate_04[i]
BERT_VQ_rate_04
# Out:
#             13    21    42    87    100
# CoLA       15.9     9   3.5  -0.1  19.8
# SST-2      80.3  75.8  71.8  80.6  84.5
# MRPC(F1)   69.3  58.3  68.8  73.4    80
# MRPC(Acc)  60.9  52.1  66.3  61.4  62.6
# QQP(F1)    38.2  37.4  31.6    42  34.9
# QQP(Acc)   60.4  68.9  66.7  71.4  51.5
# MNLI-m     31.7  33.1  32.3  34.5  36.3
# MNLI-mm    32.3  29.1    36  34.6  38.1
# QNLI       53.7  51.9  52.2  49.8  51.3
# RTE          50  49.1  50.3  49.1  49.3
# WNLI       55.5  45.9  58.2  58.9  43.2

# %%
table_BERT_VQ_BEST = [[6.3, 12.9, 12.2, 10.3, 20.2],
[80.3, 75.8, 71.8, 80.6, 84.5],
[75.4, 59.8, 74.6, 68.5, 79.8],
[63, 53.3, 64, 57.9, 67.8],
[61.2, 32.6, 30.8, 42.4, 35.8],
[58.8, 74.4, 70.1, 69.1, 62.5],
[34.1, 32.7, 33.5, 35.4, 35.9],
[34.7, 32, 32.2, 38.8, 37.7],
[53.7, 51.9, 52.2, 49.8, 51.3],
[50, 49.1, 50.3, 49.1, 49.3],
[54.1, 41.8, 53.4, 63, 51.4]
]

for i in range(len(table_BERT_VQ_BEST)):
    BERT_VQ_BEST.iloc[i] = table_BERT_VQ_BEST[i]
BERT_VQ_BEST
# Out:
#             13    21    42    87    100
# CoLA        6.3  12.9  12.2  10.3  20.2
# SST-2      80.3  75.8  71.8  80.6  84.5
# MRPC(F1)   75.4  59.8  74.6  68.5  79.8
# MRPC(Acc)    63  53.3    64  57.9  67.8
# QQP(F1)    61.2  32.6  30.8  42.4  35.8
# QQP(Acc)   58.8  74.4  70.1  69.1  62.5
# MNLI-m     34.1  32.7  33.5  35.4  35.9
# MNLI-mm    34.7    32  32.2  38.8  37.7
# QNLI       53.7  51.9  52.2  49.8  51.3
# RTE          50  49.1  50.3  49.1  49.3
# WNLI       54.1  41.8  53.4    63  51.4

# %%
table_BERT_EDA = [[5.6, 12.6, 12.1, 7, 15.1],
[81.8, 73.2, 72.7, 82.8, 80.6],
[73, 60.7, 75.7, 78.1, 78.2],
[59.7, 57.2, 67.5, 63.1, 62.3],
[31.9, 37.4, 28.8, 41.6, 33.8],
[32.5, 48.6, 44.2, 69.6, 35.7],
[32.2, 31.7, 31.5, 33, 34.4],
[31, 31.4, 31.1, 33.7, 34.9],
[51.5, 44, 51.1, 50.7, 51.9],
[50.3, 49.1, 50.6, 46.8, 51.3],
[55.5, 48.6, 35.6, 63, 59.6]
]

for i in range(len(table_BERT_EDA)):
    BERT_EDA.iloc[i] = table_BERT_EDA[i]
BERT_EDA
# Out:
#             13    21    42    87    100
# CoLA        5.6  12.6  12.1     7  15.1
# SST-2      81.8  73.2  72.7  82.8  80.6
# MRPC(F1)     73  60.7  75.7  78.1  78.2
# MRPC(Acc)  59.7  57.2  67.5  63.1  62.3
# QQP(F1)    31.9  37.4  28.8  41.6  33.8
# QQP(Acc)   32.5  48.6  44.2  69.6  35.7
# MNLI-m     32.2  31.7  31.5    33  34.4
# MNLI-mm      31  31.4  31.1  33.7  34.9
# QNLI       51.5    44  51.1  50.7  51.9
# RTE        50.3  49.1  50.6  46.8  51.3
# WNLI       55.5  48.6  35.6    63  59.6

# %%
table_BERT_GAN = [[4.4, 11.7, 5.3, 16.4, 23.7],
[66.3, 67.7, 70, 83.3, 83.2],
[79.4, 38.2, 76.7, 51.9, 73],
[66.7, 44.2, 65.6, 48.6, 61.9],
[35.2, 32.1, 33, 43.2, 35.2],
[62, 54.7, 62.6, 64.4, 52.6],
[32.7, 33.9, 33.7, 33.5, 37.7],
[33.1, 33, 36.6, 34.2, 38.7],
[51.6, 45.2, 47.2, 50.6, 48.4],
[50.9, 49.8, 49.3, 48.7, 49.5],
[48.6, 44.5, 61.6, 65.1, 48.6]
]

for i in range(len(table_BERT_GAN)):
    BERT_GAN.iloc[i] = table_BERT_GAN[i]
BERT_GAN
# Out:
#             13    21    42    87    100
# CoLA        4.4  11.7   5.3  16.4  23.7
# SST-2      66.3  67.7    70  83.3  83.2
# MRPC(F1)   79.4  38.2  76.7  51.9    73
# MRPC(Acc)  66.7  44.2  65.6  48.6  61.9
# QQP(F1)    35.2  32.1    33  43.2  35.2
# QQP(Acc)     62  54.7  62.6  64.4  52.6
# MNLI-m     32.7  33.9  33.7  33.5  37.7
# MNLI-mm    33.1    33  36.6  34.2  38.7
# QNLI       51.6  45.2  47.2  50.6  48.4
# RTE        50.9  49.8  49.3  48.7  49.5
# WNLI       48.6  44.5  61.6  65.1  48.6

# %%
total_data = {'RoBERTa_conven': RoBERTa_conven, 'RoBERTa_VQ_rate_0': RoBERTa_VQ_rate_0, 'RoBERTa_VQ_rate_02': RoBERTa_VQ_rate_02, 'RoBERTa_VQ_rate_04': RoBERTa_VQ_rate_04, 'RoBERTa_VQ_BEST': RoBERTa_VQ_BEST, 'RoBERTa_EDA': RoBERTa_EDA, 'RoBERTa_GAN': RoBERTa_GAN, 'BERT_conven': BERT_conven, 'BERT_VQ_rate_0': BERT_VQ_rate_0, 'BERT_VQ_rate_02': BERT_VQ_rate_02, 'BERT_VQ_rate_04': BERT_VQ_rate_04, 'BERT_VQ_BEST': BERT_VQ_BEST, 'BERT_EDA': BERT_EDA, 'BERT_GAN': BERT_GAN}

# %%
import pickle
with open('total_data.pickle', 'wb') as f:
    pickle.dump(total_data, f)

# %%
import pickle
with open('total_data.pickle', 'rb') as f:
    total_data_import = pickle.load(f)

# %%
total_data_import.keys()
# Out:
# dict_keys(['RoBERTa_conven', 'RoBERTa_VQ_rate_0', 'RoBERTa_VQ_rate_02', 'RoBERTa_VQ_rate_04', 'RoBERTa_VQ_BEST', 'RoBERTa_EDA', 'RoBERTa_GAN', 'BERT_conven', 'BERT_VQ_rate_0', 'BERT_VQ_rate_02', 'BERT_VQ_rate_04', 'BERT_VQ_BEST', 'BERT_EDA', 'BERT_GAN'])

# %%
# fig, axs = plt.subplots(3, 3, figsize=(15, 15))
# plt.xticks(rotation=45)  # Rotate the x labels for better readability
# axs[0, 0].boxplot(data_CoLA, patch_artist=True, labels=labels)

# %%
# Generating some random data for demonstration
data_CoLA = pd.concat([total_data_import['RoBERTa_conven'].loc['CoLA'].transpose(),
            total_data_import['RoBERTa_EDA'].loc['CoLA'].transpose(),
            total_data_import['RoBERTa_GAN'].loc['CoLA'].transpose(),
            total_data_import['RoBERTa_VQ_BEST'].loc['CoLA'].transpose()], axis =1)
data_SST2 = pd.concat([total_data_import['RoBERTa_conven'].loc['SST-2'].transpose(),
            total_data_import['RoBERTa_EDA'].loc['SST-2'].transpose(),
            total_data_import['RoBERTa_GAN'].loc['SST-2'].transpose(),
            total_data_import['RoBERTa_VQ_BEST'].loc['SST-2'].transpose(),], axis = 1 )
data_MRPC = pd.concat([total_data_import['RoBERTa_conven'].loc['MRPC(F1)'].transpose(),
            total_data_import['RoBERTa_EDA'].loc['MRPC(F1)'].transpose(),
            total_data_import['RoBERTa_GAN'].loc['MRPC(F1)'].transpose(),
            total_data_import['RoBERTa_VQ_BEST'].loc['MRPC(F1)'].transpose(),], axis =1)
data_QQP = pd.concat([total_data_import['RoBERTa_conven'].loc['QQP(Acc)'].transpose(),
            total_data_import['RoBERTa_EDA'].loc['QQP(Acc)'].transpose(),
            total_data_import['RoBERTa_GAN'].loc['QQP(Acc)'].transpose(),
            total_data_import['RoBERTa_VQ_BEST'].loc['QQP(Acc)'].transpose(),], axis =1 )
data_MNLI_m = pd.concat([total_data_import['RoBERTa_conven'].loc['MNLI-m'].transpose(),
            total_data_import['RoBERTa_EDA'].loc['MNLI-m'].transpose(),
            total_data_import['RoBERTa_GAN'].loc['MNLI-m'].transpose(),
            total_data_import['RoBERTa_VQ_BEST'].loc['MNLI-m'].transpose(),], axis =1 )

data_MNLI_mm = pd.concat([total_data_import['RoBERTa_conven'].loc['MNLI-mm'].transpose(),
            total_data_import['RoBERTa_EDA'].loc['MNLI-mm'].transpose(),
            total_data_import['RoBERTa_GAN'].loc['MNLI-mm'].transpose(),
            total_data_import['RoBERTa_VQ_BEST'].loc['MNLI-mm'].transpose(),], axis =1 )

data_QNLI = pd.concat([total_data_import['RoBERTa_conven'].loc['QNLI'].transpose(),
            total_data_import['RoBERTa_EDA'].loc['QNLI'].transpose(),
            total_data_import['RoBERTa_GAN'].loc['QNLI'].transpose(),
            total_data_import['RoBERTa_VQ_BEST'].loc['QNLI'].transpose()], axis =1)

data_RTE = pd.concat([total_data_import['RoBERTa_conven'].loc['RTE'].transpose(),
            total_data_import['RoBERTa_EDA'].loc['RTE'].transpose(),
            total_data_import['RoBERTa_GAN'].loc['RTE'].transpose(),
            total_data_import['RoBERTa_VQ_BEST'].loc['RTE'].transpose()], axis =1)

data_WNLI = pd.concat([total_data_import['RoBERTa_conven'].loc['WNLI'].transpose(),
            total_data_import['RoBERTa_EDA'].loc['WNLI'].transpose(),
            total_data_import['RoBERTa_GAN'].loc['WNLI'].transpose(),
            total_data_import['RoBERTa_VQ_BEST'].loc['WNLI'].transpose()], axis =1)


# labels = ['Fine-tuning', 'VQ-TEGAN RoR = 0.0', 'VQ-TEGAN RoR = 0.2', 'VQ-TEGAN RoR = 0.4']


# Function to create a single boxplot on given axes
def create_boxplot(ax, data, labels, title, y_label):
    bplot = ax.boxplot(data, patch_artist=True, labels=labels, medianprops=dict(color='k') )
    
    # Color each box differently
    colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']
    for patch, color in zip(bplot['boxes'], colors):
        patch.set_facecolor(color)
    
    # Adding horizontal grid lines
    ax.yaxis.grid(True)
    ax.set_title(title, fontsize = 18)
    ax.set_ylabel(y_label, fontsize = 15)
    ax.tick_params(axis = 'y', labelsize = 14)
    # ax.set_xlabel(fontsize = 10)
    ax.tick_params(axis='x', labelsize = 14, rotation=0)  # Rotate the x labels for better readability
    # ax.set_xlabel(fontsize = 10)

# Create a 3x3 grid of subplots
fig, axs = plt.subplots(3, 3, figsize=(15, 15))
# Flatten the array of axes to easily iterate over it
flat_axs = axs.flatten()

# Generating some random data for demonstration purposes
# Replace these with your actual data
np.random.seed(10)  # For reproducible results
# data_sets = [np.random.normal(50 + i*5, 5, 100) for i in range(4)]
data_sets = [data_CoLA, data_SST2, data_MRPC, data_QQP, data_MNLI_m, data_MNLI_mm, data_QNLI, data_RTE, data_WNLI]

# Labels for the boxplots
labels = ['Fine-tuning', 'EDA', 'EmbedHalluc', 'Our']

# Titles for each subplot
titles = [
    '(a) CoLA (Matthew\'s correlation)', '(b) SST-2 (Accuracy)', '(c) MRPC (F1 score)',
    '(d) QQP (Accuracy)', '(e) MNLI-m (Accuracy)', '(f) MNLI-mm (Accuracy)',
    '(g) QNLI (Accuracy)', '(h) RTE (Accuracy)', '(i) WNLI (Accuracy)'
]

# Creating boxplots on each subplot axis
for i, ax in enumerate(flat_axs):
    create_boxplot(ax, data_sets[i], labels, titles[i], 'Test Score')

# Adjust layout to prevent overlap
plt.tight_layout()

# Display the plots
plt.show()

# %%
data_CoLA.columns = ['Fine-tuning', 'EDA', 'EmbedHalluc', 'VQ-TEGAN']
data_SST2.columns = ['Fine-tuning', 'EDA', 'EmbedHalluc', 'VQ-TEGAN']
data_MRPC.columns = ['Fine-tuning', 'EDA', 'EmbedHalluc', 'VQ-TEGAN']
data_QQP.columns = ['Fine-tuning', 'EDA', 'EmbedHalluc', 'VQ-TEGAN']
data_MNLI_m.columns = ['Fine-tuning', 'EDA', 'EmbedHalluc', 'VQ-TEGAN']
data_MNLI_mm.columns = ['Fine-tuning', 'EDA', 'EmbedHalluc', 'VQ-TEGAN']
data_QNLI.columns = ['Fine-tuning', 'EDA', 'EmbedHalluc', 'VQ-TEGAN']
data_RTE.columns = ['Fine-tuning', 'EDA', 'EmbedHalluc', 'VQ-TEGAN']
data_WNLI.columns = ['Fine-tuning', 'EDA', 'EmbedHalluc', 'VQ-TEGAN']

# %%
from scipy import stats

# Drop the first column which seems to be an index or identifier column
# data_CoLA = data_CoLA.drop(data_CoLA.columns[0], axis=1)

# We will use VQ-TEGAN as the test group and compare it with all other groups using t-test

vq_tegan = data_CoLA['VQ-TEGAN']

# Initialize a dictionary to store p-values
p_values = {}
t_stats = {}

# Perform t-tests and collect p-values
for method in data_CoLA.columns[:-1]:
    if method != 'VQ-TEGAN':
        # Perform an independent t-test between VQ-TEGAN and the other method
        t_stat, p_val = stats.ttest_ind(pd.to_numeric(vq_tegan), pd.to_numeric(data_CoLA[method]))
        p_values[method] = p_val
        t_stats[method] = t_stat

# Display p-values
p_values
# Out:
# {'Fine-tuning': 0.09238321161816404,
#  'EDA': 0.011132762563874255,
#  'EmbedHalluc': 0.22265472231962172}

# %%
import numpy as np
a = [10.1, 2.1, 1.2, 6.3, 5.5]

print(np.argsort(a))
print(np.sort(a))
print(np.argmin(a))
# Out:
# [2 1 4 3 0]
# [ 1.2  2.1  5.5  6.3 10.1]
# 2

# %%
pd.DataFrame(a).rank()
# Out:
#      0
# 0  1.0
# 1  2.0
# 2  4.0
# 3  3.0
# 4  5.0

# %%
x = np.array([1.48, 1.31, 0.0, 0.8])
print(np.argsort(x))

# >[2 3 1 0]
# Out:
# [2 3 1 0]

# %%
np.sort(x)
# Out:
# array([0.  , 0.8 , 1.31, 1.48])

# %%
x.argmin()
# Out:
# 2

# %%
data_CoLA
# Out:
#     Fine-tuning   EDA EmbedHalluc VQ-TEGAN
# 13          1.9     4        14.5     31.2
# 21           17  15.6        21.5     20.9
# 42         31.8  21.1        26.1       43
# 87         11.3   4.9        11.7     21.8
# 100          24  16.5        35.7     31.4

# %%
total_data_result_ = {'CoLA' : data_CoLA, 'SST-2' : data_SST2, 'MRPC' : data_MRPC, 'QQP' : data_QQP, 'MNLI-m' : data_MNLI_m, 'MNLI-mm' : data_MNLI_mm, 'QNLI' : data_QNLI, 'RTE' : data_RTE, 'WNLI' : data_WNLI}
dataset_name = list(total_data_result_.keys())

p_values_total = {}
t_stats_total = {}

for i in range(len(total_data_result_)):
    vq_tegan = total_data_result_[dataset_name[i]]['VQ-TEGAN']
    p_values = {}
    t_stats = {}
    for method in total_data_result_[dataset_name[i]].columns[:-1]:
        if method != 'VQ-TEGAN':
            # Perform an independent t-test between VQ-TEGAN and the other method
            t_stat, p_val = stats.ttest_ind(pd.to_numeric(vq_tegan), pd.to_numeric(total_data_result_[dataset_name[i]][method]),  alternative= 'two-sided')  #  greater
            p_values[method] = np.round(p_val, 3)
            t_stats[method] = np.round(t_stat, 3)
    p_values_total[dataset_name[i]] = p_values
    t_stats_total[dataset_name[i]] = t_stats
    
    print(p_values)
# Out:
# {'Fine-tuning': 0.092, 'EDA': 0.011, 'EmbedHalluc': 0.223}
# {'Fine-tuning': 0.402, 'EDA': 0.186, 'EmbedHalluc': 0.667}
# {'Fine-tuning': 0.326, 'EDA': 0.615, 'EmbedHalluc': 0.374}
# {'Fine-tuning': 0.14, 'EDA': 0.215, 'EmbedHalluc': 0.135}
# {'Fine-tuning': 0.151, 'EDA': 0.312, 'EmbedHalluc': 0.144}
# {'Fine-tuning': 0.371, 'EDA': 0.252, 'EmbedHalluc': 0.455}
# {'Fine-tuning': 0.11, 'EDA': 0.666, 'EmbedHalluc': 1.0}
# {'Fine-tuning': 0.409, 'EDA': 0.123, 'EmbedHalluc': 0.236}
# {'Fine-tuning': 0.119, 'EDA': 0.026, 'EmbedHalluc': 0.133}

# %%
total_data_result_ = {'CoLA' : data_CoLA, 'SST-2' : data_SST2, 'MRPC' : data_MRPC, 'QQP' : data_QQP, 'MNLI-m' : data_MNLI_m, 'MNLI-mm' : data_MNLI_mm, 'QNLI' : data_QNLI, 'RTE' : data_RTE, 'WNLI' : data_WNLI}
dataset_name = list(total_data_result_.keys())

p_values_total = {}
t_stats_total = {}

for i in range(len(total_data_result_)):
    vq_tegan = total_data_result_[dataset_name[i]]['VQ-TEGAN']
    p_values = {}
    t_stats = {}
    for method in total_data_result_[dataset_name[i]].columns[:-1]:
        if method != 'VQ-TEGAN':
            # Perform an independent t-test between VQ-TEGAN and the other method
            t_stat, p_val = stats.ttest_ind(pd.to_numeric(vq_tegan), pd.to_numeric(total_data_result_[dataset_name[i]][method]),  alternative= 'greater')  #  greater
            p_values[method] = np.round(p_val, 3)
            t_stats[method] = np.round(t_stat, 3)
    p_values_total[dataset_name[i]] = p_values
    t_stats_total[dataset_name[i]] = t_stats
    
    print(p_values)
# Out:
# {'Fine-tuning': 0.046, 'EDA': 0.006, 'EmbedHalluc': 0.111}
# {'Fine-tuning': 0.201, 'EDA': 0.093, 'EmbedHalluc': 0.334}
# {'Fine-tuning': 0.163, 'EDA': 0.307, 'EmbedHalluc': 0.187}
# {'Fine-tuning': 0.07, 'EDA': 0.108, 'EmbedHalluc': 0.068}
# {'Fine-tuning': 0.076, 'EDA': 0.156, 'EmbedHalluc': 0.072}
# {'Fine-tuning': 0.185, 'EDA': 0.126, 'EmbedHalluc': 0.227}
# {'Fine-tuning': 0.055, 'EDA': 0.333, 'EmbedHalluc': 0.5}
# {'Fine-tuning': 0.205, 'EDA': 0.939, 'EmbedHalluc': 0.118}
# {'Fine-tuning': 0.06, 'EDA': 0.013, 'EmbedHalluc': 0.067}

# %%
t_stats_total
# Out:
# {'CoLA': {'Fine-tuning': 1.911, 'EDA': 3.283, 'EmbedHalluc': 1.322},
#  'SST-2': {'Fine-tuning': 0.885, 'EDA': 1.448, 'EmbedHalluc': 0.446},
#  'MRPC': {'Fine-tuning': 1.046, 'EDA': 0.524, 'EmbedHalluc': 0.941},
#  'QQP': {'Fine-tuning': 1.637, 'EDA': 1.346, 'EmbedHalluc': 1.661},
#  'MNLI-m': {'Fine-tuning': 1.586, 'EDA': 1.078, 'EmbedHalluc': 1.618},
#  'MNLI-mm': {'Fine-tuning': 0.948, 'EDA': 1.235, 'EmbedHalluc': 0.785},
#  'QNLI': {'Fine-tuning': 1.797, 'EDA': 0.449, 'EmbedHalluc': 0.0},
#  'RTE': {'Fine-tuning': 0.87, 'EDA': -1.725, 'EmbedHalluc': 1.282},
#  'WNLI': {'Fine-tuning': 1.745, 'EDA': 2.717, 'EmbedHalluc': 1.671}}

# %%
p_values_total
# Out:
# {'CoLA': {'Fine-tuning': 0.046, 'EDA': 0.006, 'EmbedHalluc': 0.111},
#  'SST-2': {'Fine-tuning': 0.201, 'EDA': 0.093, 'EmbedHalluc': 0.334},
#  'MRPC': {'Fine-tuning': 0.163, 'EDA': 0.307, 'EmbedHalluc': 0.187},
#  'QQP': {'Fine-tuning': 0.07, 'EDA': 0.108, 'EmbedHalluc': 0.068},
#  'MNLI-m': {'Fine-tuning': 0.076, 'EDA': 0.156, 'EmbedHalluc': 0.072},
#  'MNLI-mm': {'Fine-tuning': 0.185, 'EDA': 0.126, 'EmbedHalluc': 0.227},
#  'QNLI': {'Fine-tuning': 0.055, 'EDA': 0.333, 'EmbedHalluc': 0.5},
#  'RTE': {'Fine-tuning': 0.205, 'EDA': 0.939, 'EmbedHalluc': 0.118},
#  'WNLI': {'Fine-tuning': 0.06, 'EDA': 0.013, 'EmbedHalluc': 0.067}}

# %%
# Generating some random data for demonstration
data_CoLA = pd.concat([total_data_import['BERT_conven'].loc['CoLA'].transpose(),
            total_data_import['BERT_EDA'].loc['CoLA'].transpose(),
            total_data_import['BERT_GAN'].loc['CoLA'].transpose(),
            total_data_import['BERT_VQ_BEST'].loc['CoLA'].transpose()], axis =1)
data_SST2 = pd.concat([total_data_import['BERT_conven'].loc['SST-2'].transpose(),
            total_data_import['BERT_EDA'].loc['SST-2'].transpose(),
            total_data_import['BERT_GAN'].loc['SST-2'].transpose(),
            total_data_import['BERT_VQ_BEST'].loc['SST-2'].transpose(),], axis = 1 )
data_MRPC = pd.concat([total_data_import['BERT_conven'].loc['MRPC(F1)'].transpose(),
            total_data_import['BERT_EDA'].loc['MRPC(F1)'].transpose(),
            total_data_import['BERT_GAN'].loc['MRPC(F1)'].transpose(),
            total_data_import['BERT_VQ_BEST'].loc['MRPC(F1)'].transpose(),], axis =1)
data_QQP = pd.concat([total_data_import['BERT_conven'].loc['QQP(Acc)'].transpose(),
            total_data_import['BERT_EDA'].loc['QQP(Acc)'].transpose(),
            total_data_import['BERT_GAN'].loc['QQP(Acc)'].transpose(),
            total_data_import['BERT_VQ_BEST'].loc['QQP(Acc)'].transpose(),], axis =1 )
data_MNLI_m = pd.concat([total_data_import['BERT_conven'].loc['MNLI-m'].transpose(),
            total_data_import['BERT_EDA'].loc['MNLI-m'].transpose(),
            total_data_import['BERT_GAN'].loc['MNLI-m'].transpose(),
            total_data_import['BERT_VQ_BEST'].loc['MNLI-m'].transpose(),], axis =1 )

data_MNLI_mm = pd.concat([total_data_import['BERT_conven'].loc['MNLI-mm'].transpose(),
            total_data_import['BERT_EDA'].loc['MNLI-mm'].transpose(),
            total_data_import['BERT_GAN'].loc['MNLI-mm'].transpose(),
            total_data_import['BERT_VQ_BEST'].loc['MNLI-mm'].transpose(),], axis =1 )

data_QNLI = pd.concat([total_data_import['BERT_conven'].loc['QNLI'].transpose(),
            total_data_import['BERT_EDA'].loc['QNLI'].transpose(),
            total_data_import['BERT_GAN'].loc['QNLI'].transpose(),
            total_data_import['BERT_VQ_BEST'].loc['QNLI'].transpose()], axis =1)

data_RTE = pd.concat([total_data_import['BERT_conven'].loc['RTE'].transpose(),
            total_data_import['BERT_EDA'].loc['RTE'].transpose(),
            total_data_import['BERT_GAN'].loc['RTE'].transpose(),
            total_data_import['BERT_VQ_BEST'].loc['RTE'].transpose()], axis =1)

data_WNLI = pd.concat([total_data_import['BERT_conven'].loc['WNLI'].transpose(),
            total_data_import['BERT_EDA'].loc['WNLI'].transpose(),
            total_data_import['BERT_GAN'].loc['WNLI'].transpose(),
            total_data_import['BERT_VQ_BEST'].loc['WNLI'].transpose()], axis =1)


# labels = ['Fine-tuning', 'VQ-TEGAN RoR = 0.0', 'VQ-TEGAN RoR = 0.2', 'VQ-TEGAN RoR = 0.4']


# Function to create a single boxplot on given axes
def create_boxplot(ax, data, labels, title, y_label):
    bplot = ax.boxplot(data, patch_artist=True, labels=labels)
    
    # Color each box differently
    colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']
    for patch, color in zip(bplot['boxes'], colors):
        patch.set_facecolor(color)
    
    # Adding horizontal grid lines
    ax.yaxis.grid(True)
    ax.set_title(title, fontsize = 18)
    ax.set_ylabel(y_label, fontsize = 15)
    ax.tick_params(axis = 'y', labelsize = 12)
    # ax.set_xlabel(fontsize = 10)
    ax.tick_params(axis='x', labelsize = 12, rotation=0)  # Rotate the x labels for better readability
    # ax.set_xlabel(fontsize = 10)

# Create a 3x3 grid of subplots
fig, axs = plt.subplots(3, 3, figsize=(15, 15))
# Flatten the array of axes to easily iterate over it
flat_axs = axs.flatten()

# Generating some random data for demonstration purposes
# Replace these with your actual data
np.random.seed(10)  # For reproducible results
# data_sets = [np.random.normal(50 + i*5, 5, 100) for i in range(4)]
data_sets = [data_CoLA, data_SST2, data_MRPC, data_QQP, data_MNLI_m, data_MNLI_mm, data_QNLI, data_RTE, data_WNLI]

# Labels for the boxplots
labels = ['Fine-tuning', 'EDA', 'EmbedHalluc', 'Our']

# Titles for each subplot
titles = [
    'CoLA (Matthew\'s correlation)', 'SST-2 (Accuracy)', 'MRPC (F1 score)',
    'QQP (Accuracy)', 'MNLI-m (Accuracy)', 'MNLI-mm (Accuracy)',
    'QNLI (Accuracy)', 'RTE (Accuracy)', 'WNLI (Accuracy)'
]

# Creating boxplots on each subplot axis
for i, ax in enumerate(flat_axs):
    create_boxplot(ax, data_sets[i], labels, titles[i], 'Test Score')

# Adjust layout to prevent overlap
plt.tight_layout()

# Display the plots
plt.show()
